# %%
import sklearn as sk
#sklearn is for models

# %%
import numpy as np

# %%
from sklearn import datasets
from sklearn import linear_model

boston = sk.datasets.load_boston()
#model type #model <- lm( target ~. , data = boston)
model = sk.linear_model.LinearRegression()
fitted_model = model.fit(boston.data , boston.target)
prediction = fitted_model.predict( boston.data )
RMSE = np.sqrt( np.mean( (boston.target - prediction)**2 ) ) 
print("The RMSE is ", RMSE)

import matplotlib.pyplot as plt #"ripoff" of matlab plotting - trying to mimic matlab plotting - pyplot is plotting tool

data = np.matrix(boston.data)
plt.plot(data[:,0],boston.target,'b*')
# Out:
# The RMSE is  4.679191295697281

# %%
import pandas as pd
#pandas is a ripoff of R
#Python ANd Data AnalySis
# no piping or tidyverse :(
    
from google.colab import files #unique to CoLab
import io

uploaded = files.upload()
# Out:
#      <input type="file" id="files-9372e6ee-3ae6-4003-9372-fcf48521dc28" name="files[]" multiple disabled />
#      <output id="result-9372e6ee-3ae6-4003-9372-fcf48521dc28">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving winequality-red.csv to winequality-red.csv

# %%
wine = pd.read_csv(io.BytesIO(uploaded['winequality-red.csv']))
wine.head(10)
wine.sort_values(by=['density'])
# Out:
#       fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 1017            8.0             0.180         0.37  ...       0.44     12.7        6
# 1018            8.0             0.180         0.37  ...       0.44     12.7        6
# 1114            5.0             0.400         0.50  ...       0.66     13.6        6
# 836             6.7             0.280         0.28  ...       0.39     11.7        7
# 837             6.7             0.280         0.28  ...       0.39     11.7        7
# ...             ...               ...          ...  ...        ...      ...      ...
# 555            15.5             0.645         0.49  ...       0.74     11.1        5
# 554            15.5             0.645         0.49  ...       0.74     11.1        5
# 442            15.6             0.685         0.76  ...       0.68     11.2        7
# 1435           10.2             0.540         0.37  ...       0.77      9.0        6
# ...
