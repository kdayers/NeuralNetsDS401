# %% [markdown]
# #Title for today
# This is some text blah blah blah with some math $f(x)=x$

# %%
for i in range(10):
  print(i**2)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %% [markdown]
# #Numpy
# Numpy is just a ripoff of MATLAB

# %%
import numpy as np #in R: library(numpy)
billy = np.array([0,1,3,5])
print(billy)

MyMatrix = np.matrix([[1,2],[3,4]])
print(MyMatrix)

np.linalg.eigvals(MyMatrix)
# Out:
# [0 1 3 5]
# [[1 2]
#  [3 4]]
# array([-0.37228132,  5.37228132])
